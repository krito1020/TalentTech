# %% [markdown]
# ## *Pasos del ciclo de vida*

# %% [markdown]
# 1. Carga de datos
# 2. Ingeneria de características
# 3. Escalado de características
# 4. Busqueda de optimización de parámetros
# 5. Entenamiento K-Means
# 6. Análisis y visialización
# 7. Guardado del modelo
# 8. Predicción

# %%
#Librerias generales
import pandas as pd
import numpy as nup
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# librerias para guardado del modelo:
import joblib
from datetime import datetime
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel("./Datasets/BD_Clientes_Productos.xlsx")
df = pd.DataFrame(data)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299169 entries, 0 to 299168
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Fecha           299169 non-null  datetime64[ns]
#  1   Nombre Cliente  299169 non-null  object
#  2   Tipo Cliente    299169 non-null  object
#  3   Departamento    299169 non-null  object
#  4   Vendedor        299169 non-null  object
#  5   Sucursal        299169 non-null  object
#  6   Categoría       299169 non-null  object
#  7   Producto        299169 non-null  object
#  8   Linea           299169 non-null  object
#  9   Cantidad        299169 non-null  int64
#  10  Venta           299169 non-null  float64
#  11  Costos          299169 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 27.4+ MB
#        Fecha                               Nombre Cliente     Tipo Cliente  \
# 0 2018-01-04            OCEANO AZUL DISTRIBUCIONES S.A.S.     DISTRIBUIDOR
# 1 2018-01-04  COMPAÑIA NACIONAL DE LEVADURAS LEVAPAN S.A.  CADENA REGIONAL
# 2 2018-01-04                     RESTAURANTE JIANBANQ MEI  CADENA REGIONAL
# 3 2018-01-04           COMERCIALIZADORA Y ASOCIADOS S.A.S  CADENA REGIONAL
# 4 2018-01-04                               RAPI MERCAR SA  CADENA REGIONAL
#
#   Departamento               Vendedor Sucursal Categoría          Producto  \
# 0    ATLANTICO  SILVIA CAROLINA LOPEZ    NORTE    LACTEA           CHEDDAR
# 1    ANTIOQUIA   PAULA ANDREA ARTEAGA   CENTRO    LACTEA  MANTEQUILLA MINI
# 2    ANTIOQUIA   PAULA ANDREA ARTEAGA   CENTRO    LACTEA  MANTEQUILLA MINI
# 3    ANTIOQUIA     VICKY BUENAVENTURA   CENTRO    LACTEA     AREQUIPE MINI
# 4    ANTIOQUIA   LINA CECILIA CARDONA   CENTRO    LACTEA    MIGUELUCHO PER
#
#               Linea  Cantidad         Venta        Costos
# 0            QUESOS         5  45107.494665  41250.000000
# 1       ESPARCIBLES         1   5717.000000   3712.872135
# 2       ESPARCIBLES         1   5717.000000   3712.872135
# 3  POSTRES Y DULCES         1   8183.000000   4537.624369
# 4  POSTRES Y DULCES         1   8756.000000   5041.475267

# %%
snapshot_date = df['Fecha'].max() + pd.Timedelta(days=1)
# Agrupaciones por clientes:
rfm_data = df.groupby('Nombre Cliente').agg({
    'Fecha': lambda date: (snapshot_date - date.max()).days, # Recencia , es decir las ventas más recientes
    'Nombre Cliente': 'count', # Frecuencia, es decir el número de compras
    'Venta': 'sum' # Monetario, es decir el total de compras
})

display(rfm_data)
# Out:
#                                Fecha  Nombre Cliente         Venta
# Nombre Cliente
#  DISTRIBUIDORA PUNTO SEIS          2              68  1.417332e+06
# 5 ESQUINAS                        46              50  9.394804e+05
# 61PRADO EUROPEAN GUESTHOUSE        2             209  3.135524e+06
# ABARROTES ALFER                   33              52  8.029471e+05
# ABARROTES CUCUTA                  39              54  7.615975e+05
# ...                              ...             ...           ...
# ZEUS                              72              11  1.812906e+05
# ZONA LOGISTICA S.A.S               1             210  4.527208e+06
# ZONA REFRESCANTE                  72              11  1.090489e+05
# ZOOCRIADERO AVES AUSTRALIANAS     71              11  1.100984e+05
# ZULUAGA LOPEZ JESUS ADAN          39             104  1.442300e+06
#
# [1993 rows x 3 columns]

# %%
# Renombrar Las columnas
rfm_data.rename(columns={
    'Fecha': 'Recencia',    
    'Nombre Cliente': 'Frecuencia',
    'Venta': 'Monetario'
}, inplace=True)
display(rfm_data)
# Out:
#                                Recencia  Frecuencia     Monetario
# Nombre Cliente
#  DISTRIBUIDORA PUNTO SEIS             2          68  1.417332e+06
# 5 ESQUINAS                           46          50  9.394804e+05
# 61PRADO EUROPEAN GUESTHOUSE           2         209  3.135524e+06
# ABARROTES ALFER                      33          52  8.029471e+05
# ABARROTES CUCUTA                     39          54  7.615975e+05
# ...                                 ...         ...           ...
# ZEUS                                 72          11  1.812906e+05
# ZONA LOGISTICA S.A.S                  1         210  4.527208e+06
# ZONA REFRESCANTE                     72          11  1.090489e+05
# ZOOCRIADERO AVES AUSTRALIANAS        71          11  1.100984e+05
# ZULUAGA LOPEZ JESUS ADAN             39         104  1.442300e+06
#
# [1993 rows x 3 columns]

# %%
# Escaladpo de los datos
scaler = StandardScaler()
rfm_scaler = scaler.fit_transform(rfm_data)

rfm_scaler_df = pd.DataFrame(rfm_scaler, index=rfm_data.index, columns=rfm_data.columns) # DataFrame con los datos escalados
display(rfm_scaler_df)
# Out:
#                                Recencia  Frecuencia  Monetario
# Nombre Cliente
#  DISTRIBUIDORA PUNTO SEIS     -1.401963   -0.113701  -0.098525
# 5 ESQUINAS                     0.147700   -0.138627  -0.134109
# 61PRADO EUROPEAN GUESTHOUSE   -1.401963    0.081548   0.029422
# ABARROTES ALFER               -0.310155   -0.135857  -0.144276
# ABARROTES CUCUTA              -0.098838   -0.133088  -0.147355
# ...                                 ...         ...        ...
# ZEUS                           1.063409   -0.192632  -0.190568
# ZONA LOGISTICA S.A.S          -1.437182    0.082933   0.133056
# ZONA REFRESCANTE               1.063409   -0.192632  -0.195948
# ZOOCRIADERO AVES AUSTRALIANAS  1.028190   -0.192632  -0.195870
# ZULUAGA LOPEZ JESUS ADAN      -0.098838   -0.063851  -0.096665
#
# [1993 rows x 3 columns]

# %%
### MÉTODO DEL CODO (WCSS)

# %%
# Buscar el valor optimo de clusters:
wcss = {}
for k in range(2, len(rfm_scaler_df.index)):
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=300, random_state=42)
    kmeans.fit(rfm_scaler_df)
    wcss[k] = kmeans.inertia_
print(wcss.keys())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       3 for k in range(2, len(rfm_scaler_df.index)):
#       4     kmeans = KMeans(n_clusters=k, n_init=10, max_iter=300, random_state=42)
# ----> 5     kmeans.fit(rfm_scaler_df)
#       6     wcss[k] = kmeans.inertia_
#       7 print(wcss.keys())
#
# File c:\Users\Soportedrai\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Soportedrai\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\cluster\_kmeans.py:1499, in KMeans.fit(self, X, y, sample_weight)
#    1495 best_inertia, best_labels = None, None
#    1497 for i in range(self._n_init):
#    1498     # Initialize centers
# -> 1499     centers_init = self._init_centroids(
#    1500         X,
#    1501         x_squared_norms=x_squared_norms,
#    1502         init=init,
#    1503         random_state=random_state,
#    1504         sample_weight=sample_weight,
#    1505     )
#    1506     if self.verbose:
#    1507         print("Initialization complete")
#
# File c:\Users\Soportedrai\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\cluster\_kmeans.py:1014, in _BaseKMeans._init_centroids(self, X, x_squared_norms, init, random_state, sample_weight, init_size, n_centroids)
#    1011     sample_weight = sample_weight[init_indices]
#    1013 if isinstance(init, str) and init == "k-means++":
# -> 1014     centers, _ = _kmeans_plusplus(
#    1015         X,
#    1016         n_clusters,
#    1017         random_state=random_state,
#    1018         x_squared_norms=x_squared_norms,
#    1019         sample_weight=sample_weight,
#    1020     )
#    1021 elif isinstance(init, str) and init == "random":
#    1022     seeds = random_state.choice(
#    1023         n_samples,
#    1024         size=n_clusters,
#    1025         replace=False,
#    1026         p=sample_weight / sample_weight.sum(),
#    1027     )
#
# File c:\Users\Soportedrai\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\cluster\_kmeans.py:245, in _kmeans_plusplus(X, n_clusters, x_squared_norms, sample_weight, random_state, n_local_trials)
#     240 for c in range(1, n_clusters):
#     241     # Choose center candidates by sampling with probability proportional
#     242     # to the squared distance to the closest existing center
#     243     rand_vals = random_state.uniform(size=n_local_trials) * current_pot
#     244     candidate_ids = np.searchsorted(
# --> 245         stable_cumsum(sample_weight * closest_dist_sq), rand_vals
#     246     )
#     247     # XXX: numerical imprecision can result in a candidate_id out of range
#     248     np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)
#
# File c:\Users\Soportedrai\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\extmath.py:1235, in stable_cumsum(arr, axis, rtol, atol)
#    1212 def stable_cumsum(arr, axis=None, rtol=1e-05, atol=1e-08):
#    1213     """Use high precision for cumsum and check that final value matches sum.
#    1214
#    1215     Warns if the final cumulative sum does not match the sum (up to the chosen
#    (...)   1233         Array with the cumulative sums along the chosen axis.
#    1234     """
# -> 1235     out = np.cumsum(arr, axis=axis, dtype=np.float64)
#    1236     expected = np.sum(arr, axis=axis, dtype=np.float64)
#    1237     if not np.allclose(
#    1238         out.take(-1, axis=axis), expected, rtol=rtol, atol=atol, equal_nan=True
#    1239     ):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:2955, in cumsum(a, axis, dtype, out)
#    2879 @array_function_dispatch(_cumsum_dispatcher)
#    2880 def cumsum(a, axis=None, dtype=None, out=None):
#    2881     """
#    2882     Return the cumulative sum of the elements along a given axis.
#    2883
#    (...)   2953
#    2954     """
# -> 2955     return _wrapfunc(a, 'cumsum', axis=axis, dtype=dtype, out=out)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
# Grafica de codo:
plt.figure(figsize=(10, 6))
plt.plot(list(wcss.keys()), list(wcss.values()), o-) #Se usa o- para que se vea la linea y los puntos
plt.title('Grafica de codo para encontrar el número óptimo de clusters (K)')
plt.xlabel('Número de clusters (K)')
plt.ylabel('WCSS - Inercia')
plt.grid(True)
plt.show()
# Out:
#   Cell In[9], line 3
#     plt.plot(list(wcss.keys()), list(wcss.values()), o-) #Se usa o- para que se vea la linea y los puntos
#                                                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## *MÉTODO DE SILUETA*

# %%
silhouette_scores = {}
for k in range(2, len(rfm_scaler_df.index)): # Buscar el valor optimo de clusters:
    kmeans = KMeans(n_clusters=k, init='k-means++', n_init=10, ramdom_state=42) # Inicializar el modelo KMeans
    kmeans.fit(rfm_scaler_df) # Ajustar el modelo KMeans
    score = silhouette_scores(rfm_scaler_df, kmeans.labels_) # Calcular el coeficiente de la silueta
    silhouette_scores[k] = score # Guardar el coeficiente de la silueta para cada k
    print(f"Coeficiente de la silueta para k={k}: {score:.4f}") # Imprimir el coeficiente de la silueta para cada k
